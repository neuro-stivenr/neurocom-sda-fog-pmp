# %%
from util import *
df_ppg = pd.read_csv('data/PPG_FOG_NEUROCOM_FINAL_v2.csv', index_col=0)
group_comparisons(df_ppg)
# Out:
#  sex
# ---
#
# Contingency table:
#  has_fog   0   1
# sex
# F        14   5
# M        45  11
#
# Percentage freezers:
#  sex
# F    26.32%
# M    19.64%
# dtype: object
#
# Result:
#  χ2=0.08
# P=0.77
#
#  dom_hnd
# ---
#
# Contingency table:
#  has_fog   0   1
# dom_hnd
# L         6   4
# R        53  12
#
# Percentage freezers:
#  dom_hnd
# L     40.0%
# R    18.46%
# dtype: object
#
# Result:
#  χ2=1.28
# P=0.26
#
#  clinical_balance_impaired
# ---
#
# Contingency table:
#  has_fog                     0   1
# clinical_balance_impaired
# N                          54  11
# Y                           5   5
#
# Percentage freezers:
#  clinical_balance_impaired
# N    16.92%
# Y     50.0%
# dtype: object
#
# Result:
#  χ2=3.85
# P=0.05*
#
#  affected_side
# ---
#
# Contingency table:
#  has_fog         0   1
# affected_side
# Eq              2   2
# L              21   4
# R              36  10
#
# Percentage freezers:
#  affected_side
# Eq     50.0%
# L      16.0%
# R     21.74%
# ...
